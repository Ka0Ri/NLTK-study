# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance("very")
# Out:
# Displaying 25 of 322 matches:
#  horse - whales , which had bones of very great value for their teeth , of whi
# n inward bruise ." -- KING HENRY . " Very like a whale ." -- HAMLET . " Which
# itself ," said Mr . Webster , " is a very striking and peculiar portion of the
# egree , some time or other , cherish very nearly the same feelings towards the
# o eat and sleep meanwhile . It was a very dubious - looking , nay , a very dar
# s a very dubious - looking , nay , a very dark and dismal night , bitingly col
#  to it , I thought that here was the very spot for cheap lodgings , and the be
# emned old craft . On one side hung a very large oilpainting so thoroughly besm
# mean ?" " Sartain , and that ' s the very reason he can ' t sell it , I guess
# hirt sleeves . But beginning to feel very cold now , half undressed as I was ,
# home at all that night , it being so very late , I made no more ado , but jump
# ...

# %%
text1.similar("very")
# Out:
# a same so last first pretty the too other only as one great white
# strange rather next entire now his

# %%
text1.common_contexts(["pretty", "very"])
# Out:
# and_soon a_large a_little be_much a_sharp

# %%
text1.dispersion_plot(["pretty", "probably", "towards"])

# %%
text1.generate()
# Out:
# Building ngram index...
# long , from one to the top - mast , and no coffin and went out a sea
# captain -- this peaking of the whales . , so as to preserve all his
# might had in former years abounding with them , they toil with their
# lances , strange tales of Southern whaling . at once the bravest
# Indians he was , after in vain strove to pierce the profundity . ?
# then ?" a levelled flame of pale , And give no chance , watch him ;
# though the line , it is to be gainsaid . have been
# 'long , from one to the top - mast , and no coffin and went out a sea\ncaptain -- this peaking of the whales . , so as to preserve all his\nmight had in former years abounding with them , they toil with their\nlances , strange tales of Southern whaling . at once the bravest\nIndians he was , after in vain strove to pierce the profundity . ?\nthen ?" a levelled flame of pale , And give no chance , watch him ;\nthough the line , it is to be gainsaid . have been'

# %%
len(set(text1)) / len(text1)
# Out:
# 0.07406285585022564

# %%
text1.count("very")
# Out:
# 311

# %%
fdist1 = FreqDist(text1)
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
fdist1['very']
# Out:
# 311

# %%
fdist_len = FreqDist(len(w) for w in text1)
fdist_len.max()
fdist_len.freq(3)
# Out:
# 0.19255882431878046

# %%
list(bigrams(text1))
print(set(text1))
# Out:
# {'ON', 'vicissitudes', 'wolfish', 'Hosea', 'doesn', 'finer', 'evilly', 'originated', 'uncompromised', 'previous', 'sadly', 'shoulder', 'Vengeance', 'communities', 'enjoying', 'laughed', 'shed', 'Kraken', 'HAS', 'rhyme', 'companionable', 'quicksilver', 'printing', 'posies', 'Medes', 'fought', 'rope', 'grazed', 'associates', 'sung', 'Know', 'groan', 'begrimed', 'babes', 'blocks', 'lava', 'Charlemagne', 'funeral', 'reconciled', 'Sphinx', 'warm', 'lividly', 'glasses', 'glide', 'layers', 'featured', 'sell', 'lengthened', 'Unmindful', 'sleepiest', 'policeman', 'congregated', 'passionately', 'tilt', 'ungentlemanly', 'journeys', 'sailors', 'practised', 'Strangest', 'beheaded', 'COMES', 'anointing', 'Davis', 'dying', 'Cannon', 'baskets', 'rearward', 'Humiliation', 'bespeak', 'knot', 'engage', 'supernatural', 'stayed', 'fly', 'sorrows', 'apartment', 'Screwed', 'popped', 'succor', 'ignorantly', 'halyards', 'spiralizes', 'incognita', 'flitted', 'unwarrantable', 'cutlets', 'dwells', 'governed', '
# ...

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
sorted(w for w in set(text1) if w.endswith('ableness'))
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted(term for term in set(text1) if 'abs' in term)
# Out:
# ['Ahabs',
#  'absence',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absorbed',
#  'absorbing',
#  'absorbingly',
#  'abstained',
#  'abstemious',
#  'abstinence',
#  'abstract',
#  'abstracted',
#  'abstraction',
#  'absurd',
#  'absurdly',
#  'crabs',
#  'dabs',
#  'slabs',
#  'stabs']

# %%
nltk.chat.chatbots(1)
